# %%
# !pip install --upgrade dask dask-cloudprovider distributed
# Out:
# Requirement already up-to-date: dask-cloudprovider in /Users/jlamb/miniconda3/lib/python3.6/site-packages (0.4.1)
# Requirement already up-to-date: distributed in /Users/jlamb/miniconda3/lib/python3.6/site-packages (2.27.0)
# Requirement already satisfied, skipping upgrade: aiobotocore>=0.10.2 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from dask-cloudprovider) (1.1.1)
# Requirement already satisfied, skipping upgrade: dask>=2.2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from dask-cloudprovider) (2.16.0)
# Requirement already satisfied, skipping upgrade: azureml-sdk>=1.0.83 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: tblib>=1.6.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (1.6.0)
# Requirement already satisfied, skipping upgrade: contextvars; python_version < "3.7" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (2.4)
# Requirement already satisfied, skipping upgrade: zict>=0.1.3 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (2.0.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (5.3.1)
# Requirement already satisfied, skipping upgrade: click>=6.6 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (7.1.2)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (47.3.1.post20200622)
# Requirement already satisfied, skipping upgrade: cloudpickle>=1.5.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (1.6.0)
# Requirement already satisfied, skipping upgrade: psutil>=5.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (5.7.0)
# Requirement already satisfied, skipping upgrade: tornado>=5; python_version < "3.8" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (6.0.4)
# Requirement already satisfied, skipping upgrade: toolz>=0.8.2 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (0.10.0)
# Requirement already satisfied, skipping upgrade: msgpack>=0.6.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (1.0.0)
# Requirement already satisfied, skipping upgrade: sortedcontainers!=2.0.0,!=2.0.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from distributed) (2.1.0)
# Requirement already satisfied, skipping upgrade: aiohttp>=3.3.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiobotocore>=0.10.2->dask-cloudprovider) (3.6.2)
# Requirement already satisfied, skipping upgrade: botocore<1.17.45,>=1.17.44 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiobotocore>=0.10.2->dask-cloudprovider) (1.17.44)
# Requirement already satisfied, skipping upgrade: aioitertools>=0.5.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiobotocore>=0.10.2->dask-cloudprovider) (0.7.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.10.10 in /Users/jlamb/.local/lib/python3.6/site-packages (from aiobotocore>=0.10.2->dask-cloudprovider) (1.11.2)
# Requirement already satisfied, skipping upgrade: azureml-core~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0.post1)
# Requirement already satisfied, skipping upgrade: azureml-dataset-runtime[fuse]~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-train~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-train-automl-client~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0.post2)
# Requirement already satisfied, skipping upgrade: immutables>=0.9 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from contextvars; python_version < "3.7"->distributed) (0.14)
# Requirement already satisfied, skipping upgrade: heapdict in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from zict>=0.1.3->distributed) (1.0.1)
# Requirement already satisfied, skipping upgrade: multidict<5.0,>=4.5 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (4.7.6)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5; python_version < "3.7" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (3.7.4.2)
# Requirement already satisfied, skipping upgrade: async-timeout<4.0,>=3.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (3.0.1)
# Requirement already satisfied, skipping upgrade: yarl<2.0,>=1.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (1.4.2)
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (19.3.0)
# Requirement already satisfied, skipping upgrade: chardet<4.0,>=2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna-ssl>=1.0; python_version < "3.7" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (1.1.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.26,>=1.20; python_version != "3.4" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=0.10.2->dask-cloudprovider) (1.25.9)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=0.10.2->dask-cloudprovider) (0.9.4)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=0.10.2->dask-cloudprovider) (2.8.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from botocore<1.17.45,>=1.17.44->aiobotocore>=0.10.2->dask-cloudprovider) (0.14)
# Requirement already satisfied, skipping upgrade: docker in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (4.2.0)
# Requirement already satisfied, skipping upgrade: SecretStorage in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (3.1.2)
# Requirement already satisfied, skipping upgrade: pathspec in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.7.0)
# Requirement already satisfied, skipping upgrade: msrestazure>=0.4.33 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.6.4)
# Requirement already satisfied, skipping upgrade: adal>=1.2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.2.4)
# Requirement already satisfied, skipping upgrade: azure-common>=1.1.12 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.1.25)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.0)
# Requirement already satisfied, skipping upgrade: jsonpickle in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.4.1)
# Requirement already satisfied, skipping upgrade: contextlib2 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.6.0.post1)
# Requirement already satisfied, skipping upgrade: pytz in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2020.1)
# Requirement already satisfied, skipping upgrade: PyJWT in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.7.1)
# Requirement already satisfied, skipping upgrade: msrest>=0.5.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.6.10)
# Requirement already satisfied, skipping upgrade: requests>=2.19.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.24.0)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.9.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource<=10.2.0,>=1.2.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (10.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization>=0.40.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.61.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage>=1.5.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (16.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry>=2.0.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.8.0)
# Requirement already satisfied, skipping upgrade: pyopenssl in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (19.1.0)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.5.1)
# Requirement already satisfied, skipping upgrade: ruamel.yaml>=0.15.35 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.16.10)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault>=0.40.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (7.0.0)
# Requirement already satisfied, skipping upgrade: azure-graphrbac>=0.40.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.61.1)
# Requirement already satisfied, skipping upgrade: azureml-dataprep<2.1.0a,>=2.0.1a in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.0.10)
# Requirement already satisfied, skipping upgrade: pyarrow<2.0.0,>=0.17.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.0.1)
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (3.0.1)
# Requirement already satisfied, skipping upgrade: azureml-train-core~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-train~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-steps~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-pipeline~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-pipeline-core~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-pipeline~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-automl-core~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-train-automl-client~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: azureml-telemetry~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-train-automl-client~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: idna>=2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from yarl<2.0,>=1.0->aiohttp>=3.3.1->aiobotocore>=0.10.2->dask-cloudprovider) (2.9)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.17.45,>=1.17.44->aiobotocore>=0.10.2->dask-cloudprovider) (1.15.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages/websocket_client-0.53.0-py3.6.egg (from docker->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.53.0)
# Requirement already satisfied, skipping upgrade: jeepney>=0.4.2 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.4.3)
# Requirement already satisfied, skipping upgrade: backports.weakref in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.0.post1)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.6.1)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.6.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2020.6.20)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.3.0)
# Requirement already satisfied, skipping upgrade: cffi!=1.11.3,>=1.8 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.14.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-core<2.0.0,>=1.2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azure-mgmt-storage>=1.5.0->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.4.8)
# Requirement already satisfied, skipping upgrade: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from ruamel.yaml>=0.15.35->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.2.0)
# Requirement already satisfied, skipping upgrade: azure-identity<1.3.0,>=1.2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.2.0)
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.1.16)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<21.0.0,>=20.1.1 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (20.1.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.14 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from pyarrow<2.0.0,>=0.17.0->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.18.5)
# Requirement already satisfied, skipping upgrade: azureml-train-restclients-hyperdrive~=1.13.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-train-core~=1.13.0->azureml-train~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.13.0)
# Requirement already satisfied, skipping upgrade: applicationinsights in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azureml-telemetry~=1.13.0->azureml-train-automl-client~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.11.9)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /Users/jlamb/.local/lib/python3.6/site-packages (from importlib-metadata->jsonpickle->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.5.1)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (3.1.0)
# Requirement already satisfied, skipping upgrade: pycparser in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (2.20)
# Requirement already satisfied, skipping upgrade: azure-core<2.0.0,>=1.7.0.dev in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-storage>=1.5.0->azureml-core~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.8.1)
# Requirement already satisfied, skipping upgrade: msal-extensions~=0.1.3 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (0.1.3)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.0.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.5.0)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.5.0)
# Requirement already satisfied, skipping upgrade: portalocker~=1.0 in /Users/jlamb/miniconda3/lib/python3.6/site-packages (from msal-extensions~=0.1.3->azure-identity<1.3.0,>=1.2.0->azureml-dataprep<2.1.0a,>=2.0.1a->azureml-dataset-runtime[fuse]~=1.13.0->azureml-sdk>=1.0.83->dask-cloudprovider) (1.7.1)

# %%
import os
from dask_cloudprovider import FargateCluster
from distributed import Client

os.environ["AWS_DEFAULT_REGION"] = "us-east-2"

# %%
cluster = FargateCluster(
    name="dask-iz-gr8",
    image="daskdev/dask:latest",
    worker_mem=16384,
    n_workers=1,
    fargate_use_private_ip=False,
    scheduler_timeout="15 minutes",
)
# Out:
# /Users/jlamb/miniconda3/lib/python3.6/contextlib.py:88: UserWarning: Creating your cluster is taking a surprisingly long time. This is likely due to pending resources on AWS. Hang tight!
#   next(self.gen)

# %%
print(cluster)
# Out:
# dask-iz-gr8('tcp://18.224.200.172:8786', workers=1, threads=4, memory=16.00 GB)

# %%
client = Client(
    cluster.scheduler_address
)
# Out:
# /Users/jlamb/miniconda3/lib/python3.6/site-packages/distributed/client.py:1130: VersionMismatchWarning: Mismatched versions found
#
# +-------------+----------------+---------------+---------------+
# | Package     | client         | scheduler     | workers       |
# +-------------+----------------+---------------+---------------+
# | blosc       | None           | 1.9.2         | 1.9.2         |
# | dask        | 2.16.0         | 2.26.0        | 2.26.0        |
# | distributed | 2.27.0         | 2.26.0        | 2.26.0        |
# | lz4         | None           | 3.1.0         | 3.1.0         |
# | numpy       | 1.18.5         | 1.18.1        | 1.18.1        |
# | python      | 3.6.10.final.0 | 3.8.0.final.0 | 3.8.0.final.0 |
# +-------------+----------------+---------------+---------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# distributed.client - ERROR - Failed to reconnect to scheduler after 10.00 seconds, closing client
# ERROR - _GatheringFuture exception was never retrieved
# future: <_GatheringFuture finished exception=CancelledError()>
# concurrent.futures._base.CancelledError

# %% [markdown]
# # references
#
# * https://docs.prefect.io/orchestration/execution/dask_cloud_provider_environment.html#process

# %%
dir(Client)
# Out:
# ['__aenter__',
#  '__aexit__',
#  '__await__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancel',
#  '_close',
#  '_dec_ref',
#  '_ensure_connected',
#  '_expand_key',
#  '_expand_resources',
#  '_expand_retries',
#  '_gather',
#  '_gather_remote',
#  '_get_dataset',
#  '_get_scheduler_info',
#  '_get_task_stream',
#  '_get_versions',
#  '_graph_to_futures',
#  '_handle_cancelled_key',
#  '_handle_error',
#  '_handle_key_in_memory',
#  '_handle_lost_data',
#  '_handle_report',
#  '_handle_restart',
#  '_handle_retried_key',
#  '_handle_task_erred',
#  '_heartbeat',
#  '_inc_ref',
#  '_instances',
#  '_optimize_insert_futures',
#  '_profile',
#  '_publish_dataset',
#  '_rebalance',
#  '_reconnect',
#  '_register_worker_plugin',
#  '_release_key',
#  '_replicate',
#  '_repr_html_',
#  '_restart',
#  '_retry',
#  '_run',
#  '_run_on_scheduler',
#  '_scatter',
#  '_send_to_scheduler',
#  '_send_to_scheduler_safe',
#  '_shutdown',
#  '_start',
#  '_start_ipython_workers',
#  '_update_scheduler_info',
#  '_upload_file',
#  '_upload_large_file',
#  '_wait_for_workers',
#  'as_current',
#  'asynchronous',
#  'call_stack',
#  'cancel',
#  'close',
#  'collections_to_dsk',
#  'compute',
#  'current',
#  'dashboard_link',
#  'futures_of',
#  'gather',
#  'get',
#  'get_dataset',
#  'get_executor',
#  'get_metadata',
#  'get_restrictions',
#  'get_scheduler_logs',
#  'get_task_stream',
#  'get_versions',
#  'get_worker_logs',
#  'has_what',
#  'list_datasets',
#  'map',
#  'nbytes',
#  'ncores',
#  'normalize_collection',
#  'nthreads',
#  'persist',
#  'processing',
#  'profile',
#  'publish_dataset',
#  'rebalance',
#  'register_worker_callbacks',
#  'register_worker_plugin',
#  'replicate',
#  'restart',
#  'retire_workers',
#  'retry',
#  'run',
#  'run_coroutine',
#  'run_on_scheduler',
#  'scatter',
#  'scheduler_info',
#  'set_metadata',
#  'shutdown',
#  'start',
#  'start_ipython',
#  'start_ipython_scheduler',
#  'start_ipython_workers',
#  'submit',
#  'sync',
#  'unpublish_dataset',
#  'upload_file',
#  'wait_for_workers',
#  'who_has',
#  'write_scheduler_file']
